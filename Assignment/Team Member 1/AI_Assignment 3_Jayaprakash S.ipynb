# %% [markdown]
# # Unzip and Load Dataset

# %%
from zipfile import ZipFile
file_name = "Flowers-Dataset.zip"
with ZipFile(file_name, 'r') as zip:
    zip.printdir()
    zip.extractall()
# Out:
# File Name                                             Modified             Size
# flowers/daisy/100080576_f52e8ee070_n.jpg       2021-07-16 16:01:08        26797
# flowers/daisy/10140303196_b88d3d6cec.jpg       2021-07-16 16:01:08       117247
# flowers/daisy/10172379554_b296050f82_n.jpg     2021-07-16 16:01:08        36410
# flowers/daisy/10172567486_2748826a8b.jpg       2021-07-16 16:01:08       102862
# flowers/daisy/10172636503_21bededa75_n.jpg     2021-07-16 16:01:08        27419
# flowers/daisy/102841525_bd6628ae3c.jpg         2021-07-16 16:01:08       132803
# flowers/daisy/10300722094_28fa978807_n.jpg     2021-07-16 16:01:08        29941
# flowers/daisy/1031799732_e7f4008c03.jpg        2021-07-16 16:01:08       102618
# flowers/daisy/10391248763_1d16681106_n.jpg     2021-07-16 16:01:08        51688
# flowers/daisy/10437754174_22ec990b77_m.jpg     2021-07-16 16:01:08        13946
# flowers/daisy/10437770546_8bb6f7bdd3_m.jpg     2021-07-16 16:01:08        13518
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout,Conv2D,Flatten,MaxPool2D,Reshape,InputLayer
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # Image Augmentation

# %%
path = 'flowers/'

# %%
train_data_gen = ImageDataGenerator(rescale = 1./255,shear_range = 0.2,zoom_range = 0.2,
                             horizontal_flip = True, validation_split = 0.30)

test_data_gen = ImageDataGenerator(rescale = 1./255,validation_split = 0.30)

# %%
training_set = train_data_gen.flow_from_directory(path,target_size=(64,64),batch_size=100,class_mode='categorical',
                                                  shuffle=True,color_mode='rgb',subset = 'training')

testing_set = test_data_gen.flow_from_directory(path,target_size=(64,64),batch_size=100,class_mode='categorical',
                                                shuffle=True,color_mode='rgb',subset = 'validation')
# Out:
# Found 3024 images belonging to 5 classes.
# Found 1293 images belonging to 5 classes.

# %% [markdown]
# # Create Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D,MaxPooling2D,Flatten,Dense
img_height = 180
img_width = 180
batch_size = 32

model = Sequential()

train_ds = tf.keras.utils.image_dataset_from_directory(
  path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4317 files belonging to 5 classes.
# Using 3454 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4317 files belonging to 5 classes.
# Using 863 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %%
plt.figure(figsize=(18, 10))
for images, labels in train_ds.take(1):
    
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# # Add Layers (Convolution,MaxPooling,Flatten,Dense-(Hidden Layers),Output)

# %%
#convolution, Pooling layer 1
model.add(Conv2D(filters=48,kernel_size=3,activation='relu',input_shape=(64,64,3)))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#convolution, Pooling layer 2
model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#Flattening images
model.add(Flatten())

#Fully Connected layers
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 62, 62, 48)        1344
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 48)       0
#  )
#
#  dropout (Dropout)           (None, 31, 31, 48)        0
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        13856
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 64)                401472
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# ...
# Total params: 416,997
# Trainable params: 416,997
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compile the model

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
len(training_set)
# Out:
# 31

# %% [markdown]
# # Fit the model

# %%
early_stop = EarlyStopping(monitor='val_accuracy',patience=5,verbose=1,mode='auto')

lr = ReduceLROnPlateau(monitor='val_accuracy',factor=0.2,patience=5,min_lr=0.00001)

callback = [early_stop,lr]

# %%
result = model.fit(x=training_set, validation_data=testing_set, epochs=10)
# Out:
# Epoch 1/10
# 31/31 [==============================] - 208s 6s/step - loss: 1.4662 - accuracy: 0.3294 - val_loss: 1.2906 - val_accuracy: 0.4354
# Epoch 2/10
# 31/31 [==============================] - 66s 2s/step - loss: 1.2424 - accuracy: 0.4673 - val_loss: 1.2126 - val_accuracy: 0.4710
# Epoch 3/10
# 31/31 [==============================] - 82s 3s/step - loss: 1.1567 - accuracy: 0.5106 - val_loss: 1.1263 - val_accuracy: 0.5406
# Epoch 4/10
# 31/31 [==============================] - 77s 2s/step - loss: 1.1146 - accuracy: 0.5351 - val_loss: 1.1362 - val_accuracy: 0.5143
# Epoch 5/10
# 31/31 [==============================] - 53s 2s/step - loss: 1.0651 - accuracy: 0.5708 - val_loss: 1.0650 - val_accuracy: 0.5870
# Epoch 6/10
# 31/31 [==============================] - 54s 2s/step - loss: 1.0239 - accuracy: 0.5933 - val_loss: 1.0327 - val_accuracy: 0.5963
# Epoch 7/10
# ...

# %% [markdown]
# # Loss and Accuracy check using plot

# %%
#loss
plt.plot(result.history['loss'], label='train loss')
plt.plot(result.history['val_loss'], label='val loss')
plt.legend()
plt.show()

#accuracy
plt.plot(result.history['accuracy'], label='train acc')
plt.plot(result.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %% [markdown]
# # Save the model

# %%
model.save('flower.h5')

# %% [markdown]
# # Test the model

# %%
training_set.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
classes = ['Daisy','Dandelion','Rose','Sunflower','Tulip'] 
def testing(img):
    img = image.load_img(img,target_size=(64,64)) 
    x = image.img_to_array(img) 
    x = np.expand_dims(x,axis=0) 
    pred = np.argmax(model.predict(x)) 
    return print("Predicted class as:",classes[pred])

def img_show(img):
    img1 = image.load_img(img,target_size=(1024,1024)) 
    plt.imshow(img1)

# %%
#tests
img_show('flowers/sunflower/1008566138_6927679c8a.jpg')
testing('flowers/sunflower/1008566138_6927679c8a.jpg')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted class as: Sunflower

# %%
img_show('flowers/tulip/14039129738_cc3ac0a623_n.jpg')
testing('flowers/tulip/14039129738_cc3ac0a623_n.jpg')
# Out:
# 1/1 [==============================] - 0s 44ms/step
# Predicted class as: Tulip

# %%
img_show('flowers/dandelion/10043234166_e6dd915111_n.jpg')
testing('flowers/dandelion/10043234166_e6dd915111_n.jpg')
# Out:
# 1/1 [==============================] - 0s 43ms/step
# Predicted class as: Daisy

# %%
img_show('flowers/daisy/10172567486_2748826a8b.jpg')
testing('flowers/daisy/10172567486_2748826a8b.jpg')
# Out:
# 1/1 [==============================] - 0s 51ms/step
# Predicted class as: Tulip
